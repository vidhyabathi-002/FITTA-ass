# %%
class training:
    inmae = 'FITA'
    head = 'ram'
    location = 'plk'

    def __init__(self, name, age, deg, yop, mark):
        self.name= name
        self.age = age
        self.deg = deg
        self.yop = yop
        self.mark = mark

# object creation (outside class)
s1 = training('vidhya', 20, 'b.tech', 2026, 94)
s2 = training('sri', 21, 'b.tech', 2025, 90)
s3 = training('monya', 22, 'b.tech', 2024, 92)

# print attributes
print(s1.name, s1.age, s1.deg, s1.yop, s1.mark,sep=',' )
print("institute name:", training.inmae,",","founder:", training.head, ",","location:" , training.location)
# Out:
# vidhya,20,b.tech,2026,94
# institute name: FITA , founder: ram , location: plk

# %% [markdown]
# class method

# %%
class training:
    iname = 'FITA'
    head = 'ram'
    location = 'plk'

    # constructor
    def __init__(self, name, age, deg, yop, mark):
        self.name = name
        self.age = age
        self.deg = deg
        self.yop = yop
        self.mark = mark

    # object method
    def studentdetails(self):
        print(self.name, self.age, self.deg, self.yop, self.mark)

    # class method
    @classmethod
    def instituedetails(cls):
        print(cls.iname, cls.head, cls.location)
    # static method

    @staticmethod
    def reversename(name):
        name = name[::-1]
        return name
        




# object creation
s1 = training('vidhya', 20, 'b.tech', 2026, 94)
s1.studentdetails()

s2 = training('sri', 21, 'b.tech', 2025, 90)
s2.studentdetails()

s3 = training('monya', 22, 'b.tech', 2024, 92)
s3.studentdetails()

# class method call
training.instituedetails()

# static method call
print(training.reversename('vidhya'))
# Out:
# vidhya 20 b.tech 2026 94
# sri 21 b.tech 2025 90
# monya 22 b.tech 2024 92
# FITA ram plk
# ayhdiv

# %% [markdown]
# day 2   30-04-26

# %%
##object orintaed programming concepts
# car
numofwheel=4
milage=40.2
noofairbages=2
def moveforward():
    print("carmove forward")

def backward():
    print("car move backward")

# craeting the another car details with defining the class

numofwheel1=5
millage1=50.2
noofairbages1=4
#object method
def moveforward1():
    print("car move forward")
#object method
def backward1():
    print("car move backward")



# creating the class
class car:
        numofwheel=4
        milage=40.2
        noofairbages=2
        def moveforward(tvk):# self is replaced by tvk ints option but we write somting idinty the name 
            
            print("car move forward")   
        def backward(tvk):
            print("car move backward")
#object creation 
car1=car()
print(f"car1 noofwheel:{car1.numofwheel}")
print(f"car milage:{car1.milage}")
#property only change by object
car2=car()
car2.milage=100.0
print(car2.milage)



#reusability of code 

car3=car()
car3.moveforward()
car3.backward()
# Out:
# car1 noofwheel:4
# car milage:40.2
# 100.0
# car move forward
# car move backward

# %%
class Bank:
    bankname = 'SBI'
    branch = 'chennai'
    ifsc = 123456789


    def 
    # constructor
    def customer(self, name, account_no, acc_type, balance, branch):
        self.name = name
        self.account_no = account_no
        self.acc_type = acc_type
        self.balance = balance
        self.branch = branch
    
    def customerdetails(self):
       print(F"Customer name is {self.name}, account number is {self.account_no}, account type is {self.acc_type}, balance is {self.balance} and branch is {self.branch}")
   

# object creation
customer1 = Bank('vidhya', 1111111, 'savings', 10000, 'chennai')
customer1.customerdetails()
print(f"bankname: {Bank.bankname}, branch: {Bank.branch}, ifsc: {Bank.ifsc} ")
# Out:
#   Cell In[76], line 7
#     def
#         ^
# SyntaxError: invalid syntax

# %%
class A:
    name="rio"
    def __init__(self):
        print("A")

class B(A):
    def __init__(self):
        super().__init__()
        print("B")

b=B()
print(b.name)
# Out:
# A
# B
# rio

# %%
#bank 01
bankname='sbi'
branch='chennai'        
ifsc=123456789
#
def bank_ifsc_correct():
    print("account is correct branch dtected")

def bank_ifsc_incorrect():
    print("account is incorrect branch not detected")

#bank 02
bankname='hdfc'
branch='chennai'
ifsc=987654321


def bank_ifsc_correct():
    print("account is correct branch dtected")
def bank_ifsc_incorrect():
    print("account is incorrect branch not detected")



class bank:
    bankname='sbi'
    branch='chennai'        
    ifsc=123456789
    def bank_ifsc_correct():
        print("account is correct branch dtected")
    def bank_ifsc_incorrect():
        print("account is incorrect branch not detected")

bank1=bank()
print(bank1.bankname,bank1.branch,bank1.ifsc)

bank1.bankname='icici'
print(bank1.bankname)
# Out:
# sbi chennai 123456789
# icici

# %%
class Bank:
    bankname = 'SBI'
    branch = 'chennai'
    ifsc = 123456789
 
    # constructor
    def customer(self, name, account_no, acc_type, balance, branch):
        self.name = name
        self.account_no = account_no
        self.acc_type = acc_type
        self.balance = balance
        self.branch = branch
    # check balance     
    def bankbalancecheck(self):
        n=input("enter the yes or no for check balance")
        if n=="yes":
            print(f"your balance is {self.balance}")
            if self.balance<5000:
                print("your balance is low")
            else :
                return
            
        else:
            print("thank you for banking with us")
        
        

s1=Bank()
print(f"bankname: {s1.bankname}, branch: {s1.branch}, ifsc: {s1.ifsc} ")    
s1.customer('vidhya', 1111111, 'savings', 10000, 'chennai') 
s1.bankbalancecheck()
# Out:
# bankname: SBI, branch: chennai, ifsc: 123456789

# %%
class Bank:
    bankname = 'SBI'
    branch = 'chennai'
    ifsc = 123456789

    # customer method
    def customer(self, name, account_no, acc_type, balance, branch):
        self.name = name
        self.account_no = account_no
        self.acc_type = acc_type
        self.balance = balance
        self.branch = branch

    # check balance
    def check_balance(self):
        n = input("Enter yes or no to check balance: ")

        if n == "yes":
            print(f"Your balance is {self.balance}")

            if self.balance < 5000:
                print(" Your balance is low")

        else:
            print("Thank you for banking with us")


# object creation
s1 = Bank()

print(f"bankname: {s1.bankname}, branch: {s1.branch}, ifsc: {s1.ifsc}")

s1.customer('vidhya', 1111111, 'savings', 10000, 'chennai')

s1.check_balance()
# Out:
# bankname: SBI, branch: chennai, ifsc: 123456789
# Your balance is 10000

# %%
def addmoney(self,balance):
        n=int(input("Enter the amount to add: "))
        self.balance+=n
        print(f"Your new balance is {self.balance}")

s1.check_balance()
# Out:
# Your balance is 10000

# %%
import keyword
print(keyword.kwlist,end=',')
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield'],
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
class bank:
    bank_name = "SBI"
    loc="chennai"
    ifsc_code= "SBI0001006"

    def __init__(self,name,acc_no,acc_pin,acc_type,balance):
        self.name=name
        self.__acc_no=acc_no
        self.__acc_pin=acc_pin
        self.acc_type=acc_type
        self.__balance=balance
    
    #encapsulation
    def __deposite(self,ammount):
        self.__balance+=ammount
        print("deposite successfully")


    def __withdraw(self,ammount):
        if self.__balance>=ammount:
            self.__balance-=ammount
            print("withdraw successfully")
        else:
            print("insufficient balance")
            return False

    def authendicate(self):
        account=int(input("enter account number:"))
        pin=int(input("enter account pin:"))
        if self.__acc_no==account and self.__acc_pin==pin:
            print("authendication successful")
        else:
            print ("authendication failed")
    

    def check_balance(self):
        self.authendicate()
        print(f'your account balance is {self.__balance}')


    def deposite_money(self):
        print("--------------deposite money----------------")
        self.authendicate()
        ammount=abs(int(input("enter ammount to deposite:")))
        self.__deposite(ammount)

    def withdraw_money(self):

        print("--------------withdraw money----------------")
        self.authendicate()
        ammount=abs(int(input("enter ammount to withdraw:")))
        self.__withdraw(ammount)


    def genrate_recipt(self):
        print("--------------generate recipt----------------")
        self.authendicate()
        self.check_balance()
        


    def show_dt(self):
        print(f'name-------->{self.name}')
        print(f'bank name-------->{self.bank_name}')
        print(f'location-------->{self.loc}')
        print(f'IFSC code-------->{self.ifsc_code}')

        print(f'account number-------->{self.__acc_no}')
        
        print(f'account type-------->{self.acc_type}')
        print(f'account balance-------->{self.__balance}')



obj1=bank("sathish",12345,1234,"savings",10000)
obj1.show_dt()
obj1.deposite_money()
obj1.show_dt()
# Out:
# name-------->sathish
# bank name-------->SBI
# location-------->chennai
# IFSC code-------->SBI0001006
# account number-------->1234567890
# account type-------->savings
# account balance-------->10000
# --------------deposyte money----------------
# authendication failed
# deposite successfully
# name-------->sathish
# bank name-------->SBI
# location-------->chennai
# IFSC code-------->SBI0001006
# account number-------->1234567890
# account type-------->savings
# account balance-------->22345
