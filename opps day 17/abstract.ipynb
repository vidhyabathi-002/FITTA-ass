# %% [markdown]
# # ABSTRACTION:
#
# the pinomenon of the  hiding the complex implementation detailes while exposing the only
#
# in python to acchive the abstrction we use the abstract class and abstract method
#
# #### abstract class:
#
# * in python abstrct class is a class that cont be implemented on any functionalitys and its decided to be a blueprint of the other classs
#
# #### ABSTRACT METHOD :
#
# * an abstract method in python in python is method declear the abstrct clas but doest provied the implementation  to declear in abstrct method in python we should use the decarator called @abstract method
# * from the

# %%
from abc import ABC,abstractmethod
class animal (ABC):
    @abstractmethod
    def sound (self):
        pass

class dog(animal):
    def sound(self):
        print("dog make bark sound ")
dog=dog()
dog.sound()
#animal =animal() #Can't instantiate abstract class animal with abstract method sound
# Out:
# dog make bark sound

# %%
# maily import this 
from abc import ABC ,abstractmethod
class vechile (ABC):
    @abstractmethod
    def start (self):
        pass

class car(vechile):
    def start(self):
        print("car started ")


car=car()
car.start()
# Out:
# car started

# %% [markdown]
# QUTION FOR PROBLEM SOLVING :

# %% [markdown]
# 01.Shape ProgramWrite a Python program using abstraction for Shape.Create an abstract class ShapeCreate an abstract method area()Create a child class SquareHint: area * area

# %%
from abc import ABC, abstractmethod


# Abstract Class
class Shape(ABC):

    # Abstract Method
    @abstractmethod
    def area(self):
        pass


# Child Class
class Square(Shape):

    # Constructor
    def __init__(self, side):
        self.side = side

    # Implementing abstract method
    def area(self):
        print("Area of Square =", self.side * self.side)


# Object Creation
s = Square(4)

# Method Call
s.area()
# Out:
# Area of Square = 16

# %% [markdown]
# 2.Employee ProgramWrite a Python program using abstraction for Employee.Create abstract class EmployeeCreate abstract method salary()Create child class ManagerHint: manager salary

# %%
from abc import ABC, abstractmethod


# Abstract Class
class Employee(ABC):

    @abstractmethod
    def sal(self):
        pass


# Child Class
class Manager(Employee):

    def __init__(self, salary):
        self.salary = salary

    # Overriding abstract method
    def sal(self):
        print("Salary =", self.salary)


# Object Creation
man = Manager(70000)

# Method Call
man.sal()
# Out:
# Salary = 70000
