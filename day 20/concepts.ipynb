# %% [markdown]
# #### genrator:

# %%
def genrator():
    yield 1
    yield 2
    yield 3

gen= genrator()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %%
def genrator():
    yield 1
    yield 2
    yield 3

gen= genrator()

for i in gen:
    print ("\n",i,"\n")
# Out:
#  1
#
#
#  2
#
#
#  3
