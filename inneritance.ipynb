# %% [markdown]
# day  04-05-26
# inheritance  concepts :
#
#        Inheritance is an Object-Oriented Programming (OOP) concept where a child class inherits properties and methods from a parent class. This allows code reuse and creates a hierarchy of classes.
#
# types of inheritance :
#
#     1. Single Inheritance
#            >>>>> One child class inherits from one parent class.
#
#     2. Multiple Inheritance:
#            >>>>> One child class inherits from multiple parent classes.
#
#     3. Multilevel Inheritance
#            >>>>> A chain of inheritance - grandparent → parent → child.
#
#     4. Hierarchical Inheritance
#           >>>>> one parent class has multiple child classes.
#
#
#     5. Hybrid Inheritance
#           >>>>>>A combination of two or more types of inheritance.

# %% [markdown]
# single inheritance :

# %%
class country:#
    no_of_country =120

``
    def country_info(self):
        print("india is best country in the world")
        return


class america(country):
    no_of_country = 50



obj1=america()
print(obj1.no_of_country)
print(obj1.country_info())
# Out:
# 50
# india is best country in the world
# None

# %% [markdown]
# 1.creat a parent class name , person , display name and age  and display child class emp
# the innerite person  sal display all detailes

# %%
class  person :#  parent class
    name="rio"
    age= 12


# print statement inside the parent class
    def person_info(self):
        print("\n this is parent class detailes ")
        print(f"name of the person is :{self.name}")
        print(f"age of the person is :{self.age}")

# print statement inside the child class    
class employee(person):
    emp_id =12345
    emp_dept="mech"
    emp_salary= 50000


# print statement inside the child class
    def emp_info(self):
        print("\n this is child class detailes")
        print(f"employee id is :{self.emp_id}")
        print(f"employee dept is :{self.emp_dept}")
        print(f"employee sal info :{self.emp_salary}")



# creating object for the child class   
obj1=employee()

obj1.person_info()# call the parent class inside the child class
obj1.emp_info()# call the child class
# Out:
#  this is parent class detailes
# name of the person is :rio
# age of the person is :12
#
#  this is child class detailes
# employee id is :12345
# employee dept is :mech
# employee sal info :50000

# %% [markdown]
# 2.create a perand class animal with method eat , print animal eats ,
# then create the child class dog that in nerites fromm the animal as the method bark print dag barks

# %%
class animal:

    def animal_eats(self):
        print(f"dog eats  bone ")
       

class dog(animal):

    def dog_info(self):
        print(f"dog sound: bark")



obj1=dog()
obj1.animal_eats()
obj1.dog_info()
# Out:
# dog eats  bone
# dog sound: bark

# %% [markdown]
# 4. Hierarchical Inheritance
# One parent class has multiple child classes.
#
#
#        the  deriving the property from single parent class to multiple child class its know as hierarchical inheritance

# %%
class Parent:
    pass

class Child1(Parent):
    pass

class Child2(Parent):
    pass

class Child3(Parent):
    pass

# %%
## example company organisation
class company:
    noof_staff= 10000

    def company_info(self,loc,no_of_branch):
        print("\n this is company detailes")
        print(f"no of staffs :{self.noof_staff} ")
        print(f"company location :{loc}")
        print(f"no of branch :{no_of_branch}")
        
class redbull(company):
    noof_staff= 5000

    def redbull_info(self,no_sales):
        print("\n this is redbull company detailes")
        print(f"no of staffs :{self.noof_staff} ")
        print(f"redbull sales :{no_sales}")

class monster(company):
    noof_staff= 3000
    def monster_info(self,no_sales):
        print("\n this is monster company detailes")
        print(f"no of staffs :{self.noof_staff} ")
        print(f"monster sales :{no_sales}")
      



obj=redbull()
obj.company_info("chennai",100)
obj.redbull_info(5000)
# Out:
#  this is company detailes
# no of staffs :5000
# company location :chennai
# no of branch :100
#
#  this is redbull company detailes
# no of staffs :5000
# redbull sales :5000

# %% [markdown]
# 3.multi level inheritance
#
#
# A chain of inheritance - grandparent → parent → child.
#
#     *from one parent class  to one child class at more then once in the time its know as   the multilevel inheritance

# %%
class GrandParent:
    pass

class Parent(GrandParent):
    pass

class Child(Parent):
    pass

# %%
class paranthaman_father:
    gf_name="thevaneya pavanar"
    age=1008
    dress_code="langotta and turban"
    wife_count=5

    def grandfather_info(self):
        print("\n this is grandfather detailes")
        print(f"grandfather name :{self.gf_name}")
        print(f"grandfather age :{self.age}")
        print(f"grandfather dress code :{self.dress_code}")
        print(f"grandfather wife count :{self.wife_count   }")
# creating object for the child class
class paranthaman_own(paranthaman_father):
    name="paranthaman"
    age= 30
    dress_code="pant and shirt"
    wife_count=1

    #defining method for the child class
    def paranthaman_info(self):
        print("\n this is paranthaman detailes")
        print(f"paranthaman name :{self.name}")
        print(f"paranthaman age :{self.age}")
        print(f"paranthaman dress code :{self.dress_code}")
        print(f"paranthaman wife count :{self.wife_count}")


class paranthaman_son(paranthaman_own):
    name="santhoshkumar p"
    age=22
    dress_code="saree with blouse"
    gender="transgender (or) gay"

    def santhoskumar_info(self):
        print("\n this is santhoshkumar detailes")
        print(f"santhoshkumar name :{self.name}")
        print(f"santhoshkumar age :{self.age}")
        print(f"santhoshkumar dress code :{self.dress_code}")
        print(f"santhoshkumar gender :{self.gender  }") 



obj1=paranthaman_son()
obj1.grandfather_info()# call the grand father class inside the child class
obj1.paranthaman_info()# call the paranthaman class inside the child class      
obj1.santhoskumar_info()# call the santhoshkumar class inside the child class
# Out:
#  this is grandfather detailes
# grandfather name :thevaneya pavanar
# grandfather age :22
# grandfather dress code :saree with blouse
# grandfather wife count :1
#
#  this is paranthaman detailes
# paranthaman name :santhoshkumar p
# paranthaman age :22
# paranthaman dress code :saree with blouse
# paranthaman wife count :1
#
#  this is santhoshkumar detailes
# santhoshkumar name :santhoshkumar p
# santhoshkumar age :22
# santhoshkumar dress code :saree with blouse
# santhoshkumar gender :transgender (or) gay

# %% [markdown]
# 2. Multiple Inheritance
#
#
#         One child class inherits from multiple parent classes.

# %%
class Parent1:
    pass

class Parent2:
    pass

class Child(Parent1, Parent2):
    pass

# %%
#
class  parathiyan_father:
    hair_color="black hair"
    age=78
    wife_name ="lanister wife"


    def parathiyan_info(self):
        print(f"\n this is parathiyan father details")
        print(f"parathiyan hair color :{self.hair_color}")
        print(f"parathiyan age :{self.age}")
        print(f"parathiyan wife name :{self.wife_name}")


class lanister_wife:
    hair_color="golden hair"
    age=30
    huspand_name="parathiyan father"

    def lanister_info(self):
        print(f"\n this is lanister wife details")
        print(f"lanister hair color :{self.hair_color}")
        print(f"lanister age :{self.age}")
        print(f"lanister huspand name :{self.huspand_name} ")

class parathiyan_son(parathiyan_father,lanister_wife):
    name="jeefry parathiyan"
    age=18
    hair_color="golden hair"

    def jeefry_info(self):
        print(f"\n this is jeefry parathiyan details")
        print(f"hair color :{self.hair_color   }")
        if self.hair_color==parathiyan_father.hair_color:
            print("jeefry hair color is same as parathiyan father")
        else:
            print("Jeefry's hair color is not the same as his father's so isnot a father because his Lannister mother had relationships with another Lannister as well as his brother.")

obj.parathiyan_son()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 39
#      36         else:
#      37             print("Jeefry's hair color is not the same as his father's so isnot a father because his Lannister mother had relationships with another Lannister as well as his brother.")
# ---> 39 obj.parathiyan_son()
#
# AttributeError: 'redbull' object has no attribute 'parathiyan_son'
